# %%
folder = "D:\\Git Projects\\genesys-adversaries\\src\\media\\data\\adversaries\\"
EoTCreatures = open(folder + "EoT Adversaries.txt","r")

for line_num,line_full in enumerate(EoTCreatures):
    #Replacing tabs with spaces, then squashing to single spaces makes transforming a little easier
    line = line_full.replace('●','')
    line = line.lstrip()
    line = line.replace('\t', ' ')
    while line.find("  ") > -1:
        line = line.replace('  ', ' ')
    #I also want to remove trailing spaces from lines
    line = line.replace(' \n','\n')
        
    if line != "\n":
        print line_num
        print line
# Out:
# 0
# Atronach, Fire [Minion]
#
# 1
# Elemental Daedra, commonly known as Atronachs, are highly intelligent daedra often most often summoned by conjurers. They have no kinship or loyalties with any of the Daedric Princes, and serve all of them as they please.
#
# 2
#
# 3
# Fire Atronachs are considered the most plentiful and common, and perhaps weakest of the Atronachs. Resembling slender armoured Mer, their flesh is instead a raging flame, which turns to ash upon their demise. They posses a fierce, primal hatred with Frost Atronachs, with whom they often wage war against.
#
# 4
#
# 5
# Strength Endurance Agility Intellect Willpower Personality
#
# 6
# 1 1 2 3 3 3
#
# 7
#
# 8
# Soak: 2
#
# 9
# Wounds: 6
#
# 10
# Skills: Charm (Pers), Deception (Pers), Destruction (Will), Hand-to-Hand(Agi), Intimidate (Str), Search (Will), Vigilance (Will)
#
# 11
# Drops/Equipment: Fire Salts - Counts as Rare Herb
#
# 12
# Attacks/Weapons:
#
# 13
# Fiery Swipe - Skill: Hand-to-Hand(Agi)(GG) Range: Engaged, Damage: 7, Crit: 4, Qualities: Burn
#
# 14
# Magic Actions:
#
# 15
# Ember- Skill: Destruction(Will)(GGG) Difficulty: Average Range: Medium, Damage: 5, Crit: 3, Qualities: Burn
#
# 16
# Effity- Skill: Destruction(Will)(GGG) Difficulty: Average Range: Engaged, Damage: 5, Crit: 3, Qualities: Burn, Blast 5
#
# 17
# Talents:
#
# 18
# Daedra - Unit is a Daedra for the purpose of spellcasting, and gains a 50% damage reduction from Normal Weapons.
#
# 19
# Fire Creature - Fire Atronachs, appropriately, ignore all damage from Fire based magic. Damage dealt by Frost based magic, in contrast, deals double damage (after Soak applies).
#
# 20
# Adversary 1 - Upgrade 1 difficulty dice to all checks targeting this character.
#
# 21
# Fiery Passions - Players suffer one Setback to all Cool or Leadership checks when trying to calm an excited Fire Atronach.
#
# 22
# Special Abilities:
#
# 23
# Stoke The Flames - If damaged with Fire-based magic, the inflicted damage instead heals for the dealt amount. Any wounds healed in excess of the threshold, become temporary for the next round.
#
# 24
# Melted Weapons - If using Normal Weapons and a Despair or 5 Threat is rolled on an attack against a Fire Atronach, the weapon is consumed by the Atronach’s molten flesh, and destroyed.
#
# 25
#
# 26
# Atronach, Frost [Rival]
#
# 27
# Frost Atronachs are less common, but more imposing to mortals than their fiery rivals. Their form varies, typically depending on the intelligence of the individual Daedra. Some will resemble nothing more than an amalgamation of icy shards, while others resemble men made of ice. They share the Fire Atronach’s hatred, often responding to their threats with action.
#
# 28
#
# 29
# Strength Endurance Agility Intellect Willpower Personality
#
# 30
# 3 4 1 2 3 2
#
# 31
#
# 32
# Soak: 4
#
# 33
# Wounds: 16
#
# 34
# Skills: Charm 1 (Pers), Deception 1 (Pers), Destruction 2 (Will), Hand-to-Hand 3 (Str), Intimidate 2 (Str), Search 1 (Will), Vigilance 1 (Will)
#
# 35
# Drops/Equipment: Frost Salts - Counts as Rare Herb
#
# 36
# Attacks/Weapons:
#
# 37
# Icy Crush - Skill: Hand-to-Hand(Str)(YYY) Range: Engaged, Damage: 5, Crit: 4, Qualities: Knockdown, Disorient 2
#
# 38
# Magic Actions:
#
# 39
# Ice Spike - Skill: Destruction(Will)(YYG) Difficulty: Average Range: Medium, Damage: 5, Crit: 3, Qualities: Ensnare
#
# 40
# Talents:
#
# 41
# Daedra - Unit is a Daedra for the purpose of spellcasting, and gains a 50% damage reduction from Normal Weapons.
#
# 42
# Ice Creature - Frost Atronachs, appropriately, ignore all damage from Frost based magic. Damage dealt by Fire based magic, in contrast, deals double damage (after Soak applies).
#
# 43
# Adversary 1 - Upgrade 1 difficulty dice to all checks targeting this character.
#
# 44
# Stubborn - Players suffer one Setback to all Charm checks when trying to change a Frost Atronach’s mind.
#
# 45
# Special Abilities:
#
# 46
# Accumulation - If damaged with Frost-based magic, the inflicted damage instead heals for the dealt amount. Any wounds healed in excess of the threshold, become temporary for the next round.
#
# 47
#
# 48
#
# 49
# Atronach, Storm [Nemesis]
#
# 50
# The rarest and most powerful of the Atronachs, Storm Atronachs feel themselves above the petty squabbling of lesser Daedra. They are hard to control, dangerous, and their form varies as they please it, though typically resembles a collection of stones, laced with stormclouds.
#
# 51
#
# 52
# Strength Endurance Agility Intellect Willpower Personality
#
# 53
# 3 4 2 5 6 2
#
# 54
#
# 55
# Soak: 4
#
# 56
# Wounds: 18
#
# 57
# Strain: 18
#
# 58
# Skills: Charm 2 (Pers), Deception 3 (Pers), Destruction 5 (Will), Hand-to-Hand 3 (Str), Intimidate 2 (Str), Search 1 (Will), Vigilance 1 (Will)
#
# 59
# Drops/Equipment: Void Salts - Counts as Exceptional Herb
#
# 60
# Attacks/Weapons:
#
# 61
# Fling Stormstone - Skill: Hand-to-Hand(Str)(YYY) Range: Engaged, Damage: 8, Crit: 4, Qualities: Knockdown, Disorient 2
#
# 62
# Magic Actions:
#
# 63
# Storm Spark - Skill: Destruction(Will)(YYYYYG) Difficulty: Average Range: Medium, Damage: 6, Crit: 4, Qualities: Stun 3
#
# 64
# Talents:
#
# 65
# Daedra - Unit is a Daedra for the purpose of spellcasting, and gains a 50% damage reduction from Normal Weapons.
#
# 66
# Lightning Immunity - Storm Atronach are immune to Shock damage.
#
# 67
# Adversary 2 - Upgrade 2 difficulty dice to all checks targeting this character.
#
# 68
# Indignant - Players suffer one Setback to all Charm checks when trying to convince a Storm Atronach to care.
#
# 69
# Special Abilities:
#
# 70
# Rolling Storm- If damaged with Shock-based magic, the inflicted damage instead heals for the dealt amount. Any wounds healed in excess of the threshold, become temporary for the next round.
#
# 71
# Stormcloak - Performs a Hard Destruction check to grant itself a Lightning Cloak for one round per success. Targets caught within Engaged ranged of the Atronach must pass a Hard Acrobatics check or suffer 8 Lightning damage.
#
# 72
#
# 73
# Banekin [Minion]
#
# 74
# The smallest of all Daedric minions, Banekin resemble miniscule scamps. While they lack size and strength, Banekin seem to have a natural affinity for Shock magic, wielding more magic than the average lesser Daedra. This makes them easy to dispatch, but fairly lethal.
#
# 75
#
# 76
# Strength Endurance Agility Intellect Willpower Personality
#
# 77
# 1 1 1 1 3 1
#
# 78
#
# 79
# Soak: 1
#
# 80
# Wounds: 4
#
# 81
# Skills: Alteration(Will), Destruction (Will), Stealth(Agi)
#
# 82
# Drops/Equipment:
#
# 83
# Attacks:
#
# 84
# Claws- Skill: Hand-to-Hand(Agi) (GGG) Range: Engaged, Damage: 4, Crit: 3, Qualities: Pierce 1
#
# 85
# Magic Actions:
#
# 86
# Spark- Skill: Destruction(Will)(GGG) Difficulty: Average Range: Medium, Damage: 6, Crit: 3, Qualities: Stun 1
#
# 87
# Lightning Ball- Skill: Destruction(Will)(GGG) Difficulty: Hard Range: Medium, Damage: 6, Crit: 3, Qualities: Stun 1, Blast 4
#
# 88
# Talents:
#
# 89
# Daedra - Unit is a Daedra for the purpose of spellcasting, and gains a 50% damage reduction from Normal Weapons.
#
# 90
# Lightning Immunity - Banekin are immune to Shock damage.
#
# 91
#
# 92
# Clannfear [Rival]
#
# 93
# Clannfears are dinosaur-like Daedra that resemble a lizard with a large, bony crest on their head and a sharp beak and talons. They may represent common, wild animals in Oblivion. Due to their great speed and considerable strength, they are fearsome opponents, especially to weaker travellers. All clannfears rely upon melee attacks using their heads, beaks, and/or claws.
#
# 94
#
# 95
# Strength Endurance Agility Intellect Willpower Personality
#
# 96
# 2 3 4 1 1 2
#
# 97
#
# 98
# Soak: 4
#
# 99
# Wounds: 14
#
# 100
# Skills: Athletics 2 (Str), Hand-to-Hand 2 (Agi), Resilience 1(End), Survival 1(Will) Vigilance 1 (Will)
#
# 101
# Drops/Equipment: Clannfear Scales - counts as Rare Herb
#
# 102
# Attacks/Weapons:
#
# 103
# Beak and Claws - Skill: Hand-to-Hand (Agi) (YYYG) Range: Engaged, Damage: 6, Crit: 3, Qualities: Pierce 1
#
# 104
# Talents:
#
# 105
# Daedra - Unit is a Daedra for the purpose of spellcasting, and gains a 50% damage reduction from Normal Weapons.
#
# 106
# Adversary - Upgrade 1 difficulty dice to all checks targeting this character.
#
# 107
# Shock Weakness - Increase damage taken from all Lightning effects by 1.
#
# 108
# Special Abilities:
#
# 109
# Jagged Hide - When struck with an Engaged melee attack, attacker must pass an Average (2) Acrobatics check, or suffer 1 Wound (ignoring soak).
#
# 110
#
# 111
# Clannfear, Runt [Minion]
#
# 112
# Simply smaller, younger, less intelligent Clannfear, who often attack in packs.
#
# 113
#
# 114
# Strength Endurance Agility Intellect Willpower Personality
#
# 115
# 2 2 3 1 1 2
#
# 116
#
# 117
# Soak: 2
#
# 118
# Wounds: 7
#
# 119
# Skills: Athletics (Str), Hand-to-Hand (Agi), Resilience (End), Survival (Will) Vigilance (Will)
#
# 120
# Drops/Equipment: Clannfear Scales - counts as Rare Herb
#
# 121
# Attacks/Weapons:
#
# 122
# Beak and Claws - Skill: Hand-to-Hand (Agi) (GGG) Range: Engaged, Damage: 5, Crit: 3, Qualities: Pierce 1
#
# 123
# Talents:
#
# 124
# Daedra - Unit is a Daedra for the purpose of spellcasting, and gains a 50% damage reduction from Normal Weapons.
#
# 125
# Shock Weakness - Increase damage taken from all Shock spell effects by 1.
#
# 126
# Special Abilities:
#
# 127
# Jagged Hide - When struck with an Engaged range attack, attacker must pass an Average (2) Acrobatics check, or suffer 1 Wound (ignoring soak).
#
# 128
#
# 129
# Cultist [Minion]
#
# 130
# Every Daedric Prince, Aedra, and even some mortals have cults dedicated to them. The members of these cults are tenacious, dedicated, and in some cases ruthless. This cultist profile should be used as a baseline for any cultists, with their highest and lowest attributes traded depending on their patron. (i.e. Personality for Sanguine, or Strength for Boethiah). Skills and equipment can stay the same.
#
# 131
#
# 132
# Strength Endurance Agility Intellect Willpower Personality
#
# 133
# 3 2 1 2 2 2
#
# 134
#
# 135
# Soak: 2
#
# 136
# Wounds: 5
#
# 137
# Skills: Athletics (Str), Charm (Pers), Intimidate (Str), Deception (Pers), One-Handed (Agi), Destruction (Will), Conjuration (Int), Restoration (Will), Mysticism (Will)
#
# 138
# Drops/Equipment: Clothes/Robes matching their cause. Weapons below. Misc gold.
#
# 139
# Attacks/Weapons:
#
# 140
# Sharpened Iron Dagger - Skill: One-Handed (Agi) (G) Range: Engaged, Damage: 2, Crit: 2, Qualities: Normal Weapon, Enchanted, Pierce 1
#
# 141
# Talents:
#
# 142
# None
#
# 143
#
# 144
# Daedroth [Nemesis]
#
# 145
# Daedroths are another type of beast-like Daedra in service to Molag Bal, though are oftentimes found patrolling the realms of Oblivion as wild beasts. They resemble large crocodiles who walk upright. They are vicious, aggressive, and deadly, sporting massive teeth, claws, and powerful fire breath.
#
# 146
#
# 147
# Strength Endurance Agility Intellect Willpower Personality
#
# 148
# 5 5 4 1 3 2
#
# 149
#
# 150
# Soak: 5/4
#
# 151
# Wounds: Number
#
# 152
# Strain: Number
#
# 153
# Magick: Number
#
# 154
# Skills: Athletics 4 (Str), Hand-to-Hand 2 (Str/Agi), Resilience 5 (End), Survival 2 (Will) Vigilance 2 (Will), Destruction 4 (Will)
#
# 155
# Drops/Equipment:
#
# 156
# Attacks/Weapons:
#
# 157
# Rending Talons - Skill: Hand-to-Hand(Agi) (YYGG) Range: Engaged, Damage: 7, Crit: 3, Qualities: Pierce 2, Vicious 2, Bleed 2
#
# 158
# Bite - Skill: Hand-to-Hand(Str) (YYGGG) Range: Range, Damage: 6, Crit: 2, Qualities: Pin, Sunder
#
# 159
# Fire Breath - School: Destruction(Will)(YYYG), Difficulty: Average(PP), Range: Short, Damage: 5, Crit: 3,Qualities: Burn 3, Blast (Engaged) 4
#
# 160
# Talents:
#
# 161
# Daedra - Unit is a Daedra for the purpose of spellcasting, and gains a 50% damage reduction from Normal Weapons.
#
# 162
# Normal Weapon Immunity - Takes no damage from Normal Weapons.
#
# 163
# Adversary - Upgrade 1 difficulty dice to all checks targeting this character.
#
# 164
# Shock Weakness - Increase damage taken from all Lightning effects by 1.
#
# 165
# Special Abilities:
#
# 166
# Regeneration - Daedroths restore 1 Wound per round.
#
# 167
#
# 168
#
# 169
# Dark Seducers
#
# 170
# Possessing dusky blue-grey skin, full figured, voluptuous forms, and very little armour to cover them, the Dark Seducers stop resembling their namesake when spoken to. Perhaps as part of some cruel joke on the part of their creator Sheogorath, Dark Seducers (in stark contrast to their alluring appearance) are aggressive, dismissive and arrogant Daedra in service to the Mad God.
#
# 171
#
# 172
# Called the Mazken in their own tongue, the Dark Seducers act as the military for one half of Sheogorath’s split.. Well.. Everything. In constant rivalry with the Golden Saints who also serve their Lord, Mazken are ever eager to prove themselves capable. And they regularly succeed in that cause.
#
# 173
#
# 174
# A matriarchal society, some male Mazken do exist, though they are looked down upon by their female superiors, and rarely, if ever, hold positions of power.
#
# 175
# Dark Seducer, Kiskengo [Minion]
#
# 176
# The rank and file of the Mazken forces, Kiskengos are rarely seen outside of the Shivering Isles, and as such few mortals are aware that Dark Seducers are anything but the more powerful, better trained Mazken typically encountered on Mundus.
#
# 177
#
# 178
# Strength Endurance Agility Intellect Willpower Personality
#
# 179
# 2 2 3 2 3 1
#
# 180
#
# 181
# Soak: 4
#
# 182
# Defense: 1/1
#
# 183
# Wounds: 10
#
# 184
# Skills: Athletics (Str), Acrobatics (Agi), Charm (Pers), Cool(Will), Conjuration (Int), Deception (Pers), Illusion (Pers), Marksman (Agi), One-Handed (Agi), Two-Handed (Str), Resilience(End), Search (Will), Vigilance (Will)
#
# 185
# Drops/Equipment: Daedra Heart (Weapons/Armour considered “Bound” and non-lootable)
#
# 186
# Attacks/Weapons:
#
# 187
# Mazken Shortsword- Skill: One-Handed(Agi) (GG) Range: Engaged, Damage: 7, Crit: 3, Qualities: Pierce 3, Vicious 2
#
# 188
# Mazken Shortbow- Skill: Marksman(Agi) (GG) Range: Medium, Damage: 8, Crit: 3, Qualities: Pierce 3, Vicious 2
#
# 189
# Armour:
#
# 190
# Light Mazken Wrappings - Soak: +2, Defense: 1/1, Enc: 2, Qualities: None
#
# 191
# Talents:
#
# 192
# Daedra - Unit is a Daedra for the purpose of spellcasting, and gains a 50% damage reduction from Normal Weapons.
#
# 193
# Confidence 2 - Mazken reduce the difficulty of Fear checks by 2.
#
# 194
# Arrogance - Players suffer one Setback to all Cool or Leadership checks when attempting to sway a Mazken or Aureal..
#
# 195
# Mad God’s Visage - Mazken and Aureals gain two Boost to all Illusion spell checks.
#
# 196
#
# 197
# Dark Seducer, Autkendo [Rival]
#
# 198
# What cultists and adventurers are more likely to meet is an Autkendo. A mid-level Mazken Sergeant, Autkendos are well trained, well equipped and powerful. Sheogorath often sends them to Mundus to perform errands, and allows them to be summoned.
#
# 199
#
# 200
# Strength Endurance Agility Intellect Willpower Personality
#
# 201
# 3 3 3 3 4 2
#
# 202
#
# 203
# Soak: 5
#
# 204
# Defense: 3/3
#
# 205
# Wounds: 21
#
# 206
# Skills: Athletics 2(Str), Acrobatics 2(Agi), Charm 2(Pers), Conjuration 2(Int), Cool 2 (Will), Deception 2(Pers), Illusion 2(Pers), Intimidate 2 (Str), Marksman 1(Agi), One-Handed 2(Agi), Two-Handed 2(Str), Resilience 2 (End), Search 1(Will), Vigilance 1(Will)
#
# 207
# Drops/Equipment: Daedra Heart (Weapons/Armour considered “Bound” and non-lootable)
#
# 208
# Attacks/Weapons:
#
# 209
# Mazken Longsword- Skill: One-Handed(Agi) (YYG) Range: Engaged, Damage: 8, Crit: 3, Qualities: Pierce 3, Vicious 2
#
# 210
# Mazken Long Spear- Skill: Two-Handed(Str) (YYG) Range: Engaged, Damage: 9, Crit: 2, Qualities: Pierce 3, Vicious 2, Cumbersome 4
#
# 211
# Mazken Shortbow- Skill: Marksman(Agi) (YGG) Range: Medium, Damage: 8, Crit: 3, Qualities: Pierce 3, Vicious 2
#
# 212
# Armour:
#
# 213
# Mazken Wrappings - Soak: +2, Defense: 3/3, Enc: 2, Qualities: None
#
# 214
# Talents:
#
# 215
# Daedra - Unit is a Daedra for the purpose of spellcasting, and gains a 50% damage reduction from Normal Weapons.
#
# 216
# Normal Weapon Immunity - Takes no damage from Normal Weapons.
#
# 217
# Confidence 3 - Mazken Autkendo reduce the difficulty of Fear checks by 3.
#
# 218
# Adversary 1 - Upgrade 1 difficulty dice to all checks targeting this character.
#
# 219
# Arrogance - Players suffer one Setback to all Cool or Leadership checks when attempting to sway a Mazken or Aureal.
#
# 220
# Mad God’s Visage - Mazken and Aureals gain two Boost to all Illusion spell checks..
#
# 221
# Special Abilities:
#
# 222
# Command - As a maneuver, Autkendo can grant Boost dice to the next action performed by an ally.
#
# 223
#
# 224
# Dark Seducer, Grakendo [Nemesis]
#
# 225
# The Generals and Lords of the Mazken forces, Grakendos answer only to the Mad God himself. Having earned their position by climbing a ladder of merit (And a ladder filled with immortals), Grakendos are incredibly powerful, fierce, and well equipped. If an adventurer somehow earns the ire of a Grakendo, they had best be prepared to run.
#
# 226
#
# 227
# Strength Endurance Agility Intellect Willpower Personality
#
# 228
# 4 4 4 3 5 3
#
# 229
#
# 230
# Soak: 8
#
# 231
# Wounds: 26
#
# 232
# Defense: 3/3
#
# 233
# Skills: Athletics 3(Str), Acrobatics 2(Agi), Charm 2(Pers), Conjuration 3(Int), Cool 2 (Will), Deception 3(Pers), Illusion 3(Will), Intimidate 4 (Str), Marksman 2(Agi), One-Handed 3(Agi), Two-Handed 4(Str), Resilience 2 (End), Search 2(Will), Vigilance 2(Will)
#
# 234
# Drops/Equipment: Daedra Heart, All Weapons/Armour below
#
# 235
# Attacks/Weapons:
#
# 236
# Mazken Longsword- Skill: One-Handed(Agi) (YYYG) Range: Engaged, Damage: 8, Crit: 3, Qualities: Pierce 3, Vicious 2
#
# 237
# Mazken Claymore- Skill: Two-Handed(Str) (YYYY) Range: Engaged, Damage: 10, Crit: 2, Qualities: Pierce 3, Vicious 2, Cumbersome 3
#
# 238
# Armour:
#
# 239
# Mazken Platemail - Soak: +4, Defense: 3/3, Enc: 5, Qualities: None
#
# 240
# Talents:
#
# 241
# Daedra - Unit is a Daedra for the purpose of spellcasting, and gains a 50% damage reduction from Normal Weapons.
#
# 242
# Normal Weapon Immunity - Takes no damage from Normal Weapons.
#
# 243
# Confidence 4 - Mazken Grakendo reduce the difficulty of Fear checks by 4.
#
# 244
# Adversary 2 - Upgrade 2 difficulty dice to all checks targeting this character.
#
# 245
# Arrogance - Players suffer one Setback to all Cool or Leadership checks when attempting to sway a Mazken or Aureal.
#
# 246
# Mad God’s Visage - Mazken and Aureals gain two Boost to all Illusion spell checks..
#
# 247
# Special Abilities:
#
# 248
# Command - As a maneuver, Grakendo can grant Boost dice to the next action performed by an ally.
#
# 249
# Aura of Dementia- When in sight of a Grakendo, targets suffer one Setback to resist any Illusion spell effects.
#
# 250
#
# 251
# Dremora
#
# 252
# Dremora are Daedra of above average size, typically appearing with black-and-red faces, and sometimes small stubs of horns. They are fully sentient and most are powerful warriors or spellcasters. They are the most powerful and intelligent of the lesser daedra, to the point of governing over other daedra on behalf of their Lord. Higher-ranking Dremora are often larger in physique than a Nord male. Dremora are always heavily armored and even the spellcaster's robes provide heavy armor protection.
#
# 253
#
# 254
# Dremora are one of the rare species of Daedra which are not only sentient, but capable of human speech. Unlike other sentient species, such as Golden Saints or Dark Seducers, the Dremora primarily speak in their own language and use Nibenese only for taunting human opponents.
#
# 255
# Dremora, Caitiff [Minion]
#
# 256
# Typically used as rank and file in any Dremora outfit, Caitiffs are the lowest ranking of all Dremora, armed with simple Bound armour and weapons, and given basic training. Despite this, a Caitiff is a serious threat to a mortal combatant, and should not be taken lightly.
#
# 257
#
# 258
# Strength Endurance Agility Intellect Willpower Personality
#
# 259
# 3 2 2 3 2 2
#
# 260
#
# 261
# Soak: 4
#
# 262
# Wounds: 10
#
# 263
# Defense: 2/2
#
# 264
# Skills: Athletics (Str), Acrobatics (Agi), Charm (Pers), Cool(Will), Conjuration (Int), Deception (Pers), Destruction (Will), Marksman (Agi), One-Handed (Agi), Two-Handed (Str), Resilience(End), Search (Will), Vigilance (Will)
#
# 265
# Drops/Equipment: Daedra Heart (Weapons/Armour considered “Bound” and non-lootable)
#
# 266
# Attacks/Weapons:
#
# 267
# Daedric Shortsword- Skill: One-Handed(Agi) (GG) Range: Engaged, Damage: 7, Crit: 3, Qualities: Pierce 3, Vicious 2
#
# 268
# Daedric Shortbow- Skill: Marksman(Agi) (GG) Range: Medium, Damage: 8, Crit: 3, Qualities: Pierce 3, Vicious 2
#
# 269
# Armour:
#
# 270
# Light Daedric Cuirass - Soak: +2, Defense: 2/2, Enc: 2, Qualities: None
#
# 271
# Talents:
#
# 272
# Daedra - Unit is a Daedra for the purpose of spellcasting, and gains a 50% damage reduction from Normal Weapons.
#
# 273
# Confidence 2 - Dremora reduce the difficulty of Fear checks by 2.
#
# 274
# Determination - Summoned Dremora are exceptionally opposed to returning to Oblivion, and thus gain 2 Boost to all Banish spell checks.
#
# 275
#
# 276
# Dremora, Kynreeve [Rival]
#
# 277
# The basic Officer rank in a Dremora military outfit, Kynreeves lead groups of Dremora into battle. Still armed with Bound weapons, they are given more range in abilities, and are better trained. When a Kynreeve takes the field, mortal combatants should consider retreat.
#
# 278
#
# 279
# Strength Endurance Agility Intellect Willpower Personality
#
# 280
# 4 3 3 3 2 2
#
# 281
#
# 282
# Soak: 8
#
# 283
# Wounds: 21
#
# 284
# Skills: Athletics 2(Str), Acrobatics 2(Agi), Charm 1(Pers), Conjuration 2(Int), Cool 2 (Will), Deception 2(Pers), Destruction 2(Will), Intimidate 2 (Str), Marksman 1(Agi), One-Handed 2(Agi), Two-Handed 2(Str), Resilience 2 (End), Search 1(Will), Vigilance 1(Will)
#
# 285
# Drops/Equipment: Daedra Heart (Weapons/Armour considered “Bound” and non-lootable)
#
# 286
# Attacks/Weapons:
#
# 287
# Daedric Longsword- Skill: One-Handed(Agi) (YYG) Range: Engaged, Damage: 9, Crit: 3, Qualities: Pierce 3, Vicious 2
#
# 288
# Daedric Greataxe- Skill: Two-Handed(Str) (YYGG) Range: Engaged, Damage: 10, Crit: 2, Qualities: Pierce 3, Vicious 2, Cumbersome 4
#
# 289
# Daedric Shortbow- Skill: Marksman(Agi) (YGG) Range: Medium, Damage: 8, Crit: 3, Qualities: Pierce 3, Vicious 2
#
# 290
# Armour:
#
# 291
# Daedric Platemail - Soak: +4, Defense: 3/3, Enc: 2, Qualities: None
#
# 292
# Talents:
#
# 293
# Daedra - Unit is a Daedra for the purpose of spellcasting, and gains a 50% damage reduction from Normal Weapons.
#
# 294
# Normal Weapon Immunity - Takes no damage from Normal Weapons.
#
# 295
# Confidence 3 - Dremora Kynreeve reduce the difficulty of Fear checks by 3.
#
# 296
# Adversary 1 - Upgrade 1 difficulty dice to all checks targeting this character.
#
# 297
# Determination - Summoned Dremora are exceptionally opposed to returning to Oblivion, and thus gain 2 Boost to all Banish spell checks.
#
# 298
# Special Abilities:
#
# 299
# Command - As a maneuver, Kynreeve can grant Boost dice to the next action performed by an ally.
#
# 300
#
# 301
# Dremora, Valyknaz [Nemesis]
#
# 302
# A true Dremora Lord, Valyknaz are the supreme Lords of Dremora society. Shrouded in pure, hate-forged Daedric Platemail, and wielding jagged, fierce weaponry, a Valyknaz signals the end for most mortals. When a true Lord enters a battle, it has likely already declared victory.
#
# 303
#
# 304
# Strength Endurance Agility Intellect Willpower Personality
#
# 305
# 5 4 4 4 3 2
#
# 306
#
# 307
# Soak: 8
#
# 308
# Wounds: 31
#
# 309
# Defense: 3/3
#
# 310
# Skills: Athletics 3(Str), Acrobatics 2(Agi), Charm 2(Pers), Conjuration 3(Int), Cool 2 (Will), Discipline 5(Will), Deception 3(Pers), Destruction 3(Will), Intimidate 4 (Str), Marksman 2(Agi), One-Handed 3(Agi), Two-Handed 4(Str), Resilience 2 (End), Search 2(Will), Vigilance 2(Will)
#
# 311
# Drops/Equipment: Daedra Heart, All Weapons/Armour below
#
# 312
# Attacks/Weapons:
#
# 313
# Daedric Longsword- Skill: One-Handed(Agi) (YYYG) Range: Engaged, Damage: 10, Crit: 3, Qualities: Pierce 3, Vicious 2
#
# 314
# Daedric Claymore- Skill: Two-Handed(Str) (YYYYG) Range: Engaged, Damage: 11, Crit: 2, Qualities: Pierce 3, Vicious 2, Cumbersome 3
#
# 315
# Armour:
#
# 316
# Daedric Plate Suit - Soak: +4, Defense: 3/3, Enc: 2, Qualities: None
#
# 317
# Talents:
#
# 318
# Confidence 4 - Dremora Valyknaz reduce the difficulty of Fear checks by 4.
#
# 319
# Adversary 2 - Upgrade 2 difficulty dice to all checks targeting this character.
#
# 320
# Daedra - Unit is a Daedra for the purpose of spellcasting, and gains a 50% damage reduction from Normal Weapons.
#
# 321
# Normal Weapon Immunity - Takes no damage from Normal Weapons.
#
# 322
# Determination - Summoned Dremora are exceptionally opposed to returning to Oblivion, and thus gain 2 Boost to all Banish spell checks.
#
# 323
# Special Abilities:
#
# 324
# Command - As a maneuver, Valyknaz can grant Boost dice to the next action performed by an ally.
#
# 325
# Aura of Terror - When a Valyknaz enters combat, all characters who are aware of him, must pass a Hard (3) Cool Fear check.
#
# 326
#
# 327
# Golden Saints
#
# 328
# The Aureal (or Aureals), more commonly known as Golden Saints, are Daedric humanoids who appear as men or half-clad women with golden-hued skin wearing golden armor and a winged helmet. They serve under the command of the Daedric Prince Sheogorath. Their home is Brellach in the Shivering Isles, but despite their name, they have little love for mortals. The Aureal are a proud, arrogant race, quick to anger and cruel in their punishment. There is no question that they view all others as inferior, and make no effort to hide this in their interactions.
#
# 329
#
# 330
# They are a matriarchal society, tending to look down upon all males. Even male Golden Saints consider themselves and other males to be lesser. The Aureal make up one half of Sheogorath's army, along with the Mazken. The two groups have a great rivalry, each believing they are Sheogorath's favored. The Aureal are charged with guarding Mania.
#
# 331
#
# 332
# Golden Saint, Auren [Minion]
#
# 333
# Auren are the lowest ranking Aureal. Serving as rank and file, with the lowest grade equipment and training. Auren are rarely, if ever, seen outside of the Shivering Isles. Most males in Aureal society occupy this role.
#
# 334
#
# 335
# Strength Endurance Agility Intellect Willpower Personality
#
# 336
# 2 2 3 2 3 1
#
# 337
# Soak: 4
#
# 338
# Defense: 1/1
#
# 339
# Wounds: 10
#
# 340
# Skills: Athletics (Str), Acrobatics (Agi), Charm (Pers), Cool(Will), Conjuration (Int), Deception (Pers), Illusion (Pers), Marksman (Agi), One-Handed (Agi), Two-Handed (Str), Resilience(End), Search (Will), Vigilance (Will)
#
# 341
# Drops/Equipment: Daedra Heart (Weapons/Armour considered “Bound” and non-lootable)
#
# 342
# Attacks/Weapons:
#
# 343
# Aureal Shortsword- Skill: One-Handed(Agi) (GG) Range: Engaged, Damage: 7, Crit: 3, Qualities: Pierce 3, Vicious 2
#
# 344
# Aureal Shortbow- Skill: Marksman(Agi) (GG) Range: Medium, Damage: 8, Crit: 3, Qualities: Pierce 3, Vicious 2
#
# 345
# Armour:
#
# 346
# Light Aureal Maile - Soak: +2, Defense: 1/1, Enc: 2, Qualities: None
#
# 347
# Talents:
#
# 348
# Daedra - Unit is a Daedra for the purpose of spellcasting, and gains a 50% damage reduction from Normal Weapons.
#
# 349
# Confidence 2 - Auren reduce the difficulty of Fear checks by 2.
#
# 350
# Arrogance - Players suffer one Setback to all Cool or Leadership checks when attempting to sway a Mazken or Aureal.
#
# 351
# Mad God’s Visage - Mazken and Aureals gain two Boost to all Illusion spell checks.
#
# 352
#
# 353
#
# 354
# Golden Saint, Aurmokel [Rival]
#
# 355
# Aurmokel are the mid-tier Sergeants of the Aureal. When Sheogorath needs to send an agent to Mundus, an Aurmokel is among his options. Well equipped, trained, and highly autonomous, Aurmokel are proud agents of the Mad God.
#
# 356
#
# 357
# Strength Endurance Agility Intellect Willpower Personality
#
# 358
# 3 3 3 3 4 2
#
# 359
#
# 360
# Soak: 5
#
# 361
# Defense: 3/3
#
# 362
# Wounds: 21
#
# 363
# Skills: Athletics 2(Str), Acrobatics 2(Agi), Charm 2(Pers), Conjuration 2(Int), Cool 2 (Will), Deception 2(Pers), Illusion 2(Pers), Intimidate 2 (Str), Marksman 1(Agi), One-Handed 2(Agi), Two-Handed 2(Str), Resilience 2 (End), Search 1(Will), Vigilance 1(Will)
#
# 364
# Drops/Equipment: Daedra Heart (Weapons/Armour considered “Bound” and non-lootable)
#
# 365
# Attacks/Weapons:
#
# 366
# Aureal Longsword- Skill: One-Handed(Agi) (YYG) Range: Engaged, Damage: 8, Crit: 3, Qualities: Pierce 3, Vicious 2
#
# 367
# Aureal Long Spear- Skill: Two-Handed(Str) (YYG) Range: Engaged, Damage: 9, Crit: 2, Qualities: Pierce 3, Vicious 2, Cumbersome 4
#
# 368
# Aureal Shortbow- Skill: Marksman(Agi) (YGG) Range: Medium, Damage: 8, Crit: 3, Qualities: Pierce 3, Vicious 2
#
# 369
# Armour:
#
# 370
# Aureal Maile - Soak: +2, Defense: 3/3, Enc: 2, Qualities: None
#
# 371
# Talents:
#
# 372
# Daedra - Unit is a Daedra for the purpose of spellcasting, and gains a 50% damage reduction from Normal Weapons.
#
# 373
# Normal Weapon Immunity - Takes no damage from Normal Weapons.
#
# 374
# Confidence 3 - Aureal Aurmokel reduce the difficulty of Fear checks by 3.
#
# 375
# Adversary 1 - Upgrade 1 difficulty dice to all checks targeting this character.
#
# 376
# Arrogance - Players suffer one Setback to all Cool or Leadership checks when attempting to sway a Mazken or Aureal.
#
# 377
# Mad God’s Visage - Mazken and Aureals gain two Boost to all Illusion spell checks..
#
# 378
# Special Abilities:
#
# 379
# Command - As a maneuver, Aurmokel can grant Boost dice to the next action performed by an ally.
#
# 380
#
# 381
# Golden Saint, Pelaurig [Nemesis]
#
# 382
# The great Generals and Lords of the Aureal, Pelaurig are adorned with the finest golden armour, weapons, and training. Having earned their position and desirous of keeping it, they refuse to be defeated in battle. Ever self-confident, and perhaps more arrogant than any other Aureals, Pelaurig are easy to anger, and easier to fall to.
#
# 383
#
# 384
# Strength Endurance Agility Intellect Willpower Personality
#
# 385
# 4 4 4 3 5 3
#
# 386
#
# 387
# Soak: 8
#
# 388
# Wounds: 26
#
# 389
# Defense: 3/3
#
# 390
# Skills: Athletics 3(Str), Acrobatics 2(Agi), Charm 2(Pers), Conjuration 3(Int), Cool 2 (Will), Deception 3(Pers), Illusion 3(Will), Intimidate 4 (Str), Marksman 2(Agi), One-Handed 3(Agi), Two-Handed 4(Str), Resilience 2 (End), Search 2(Will), Vigilance 2(Will)
#
# 391
# Drops/Equipment: Daedra Heart, All Weapons/Armour below
#
# 392
# Attacks/Weapons:
#
# 393
# Aureal Longsword- Skill: One-Handed(Agi) (YYYG) Range: Engaged, Damage: 8, Crit: 3, Qualities: Pierce 3, Vicious 2
#
# 394
# Aureal Claymore- Skill: Two-Handed(Str) (YYYY) Range: Engaged, Damage: 10, Crit: 2, Qualities: Pierce 3, Vicious 2, Cumbersome 3
#
# 395
# Armour:
#
# 396
# Aureal Platemail - Soak: +4, Defense: 3/3, Enc: 5, Qualities: None
#
# 397
# Talents:
#
# 398
# Daedra - Unit is a Daedra for the purpose of spellcasting, and gains a 50% damage reduction from Normal Weapons.
#
# 399
# Normal Weapon Immunity - Takes no damage from Normal Weapons.
#
# 400
# Confidence 4 - Aureal Pelaurig reduce the difficulty of Fear checks by 4.
#
# 401
# Adversary 2 - Upgrade 2 difficulty dice to all checks targeting this character.
#
# 402
# Arrogance - Players suffer one Setback to all Cool or Leadership checks when attempting to sway a Mazken or Aureal.
#
# 403
# Mad God’s Visage - Mazken and Aureals gain two Boost to all Illusion spell checks..
#
# 404
# Special Abilities:
#
# 405
# Command - As a maneuver, Pelaurig can grant Boost dice to the next action performed by an ally.
#
# 406
# Aura of Mania- When in sight of a Pelaurig, allies may suffer 1 Strain to gain a Boost to their next action.
#
# 407
#
# 408
# Harvester [Rival]
#
# 409
# From the waist up, these servants of Molag Bal resemble four-armed women, adorned in jagged black plate. Their lower half, however, resembles a giant snake, about 8 feet long. Tasked with the gathering the souls Molag Bal feels he has earned, these dangerous Daedra wield blue flame magic, razor sharp claws, and vicious weapons.
#
# 410
#
# 411
# Strength Endurance Agility Intellect Willpower Personality
#
# 412
# 4 4 4 2 3 2
#
# 413
#
# 414
# Soak: 5
#
# 415
# Wounds: 16
#
# 416
# Magicka: 10
#
# 417
# Skills: Intimidate 2(Str), Athletics 2(Str), Two-Handed 3(Str), One-Handed 4(Agi), Destruction 1(Will)
#
# 418
# Drops/Equipment:
#
# 419
# Attacks/Weapons:
#
# 420
# 2x Daedric Shortsword- Skill: One-Handed(Agi) (YYYY) Range: Engaged, Damage: 6, Crit: 3, Qualities: Pierce 3, Vicious 2
#
# 421
# Daedric Greataxe- Skill: Two-Handed(Str) (YYYG) Range: Engaged, Damage: 10, Crit: 2, Qualities: Pierce 3, Vicious 2, Cumbersome 4
#
# 422
# Magic Actions:
#
# 423
# Blueflame - Skill: Destruction(Will)(YGG) Difficulty: Average Range: Medium, Damage: 6, Crit: 4, Qualities: Burn 3
#
# 424
# Talents:
#
# 425
# Daedra - Unit is a Daedra for the purpose of spellcasting, and gains a 50% damage reduction from Normal Weapons.
#
# 426
# Normal Weapon Immunity - Takes no damage from Normal Weapons.
#
# 427
# Rapid Reactions - Gain 1 automatic success for all initiative rolls.
#
# 428
# Many Armed - Harvesters ignore the Difficulty increase applied to making offhand attacks.
#
# 429
# Special Abilities:
#
# 430
# Rapid Strikes - Spend 1 Story Point to gain an additional action for one round.
#
# 431
#
# 432
# Hunger [Rival]
#
# 433
# Hungers are thin skinned Daedra, almost anorexic looking. They have a long tongue, sticking out of an always open round mouth. Typically regarded as minion of Boethiah, Hungers are often found in the service of Sheogorath, as he regards them fondly as pets. Hungers attempt to feed on their prey while they are alive, latching on with their sucker-like mouth and draining them.
#
# 434
#
# 435
# Strength Endurance Agility Intellect Willpower Personality
#
# 436
# 2 4 3 3 2 2
#
# 437
#
# 438
# Soak: 4
#
# 439
# Wounds: 13
#
# 440
# Skills: Hand-to-Hand 2(Agi), Intimidate 2(Str), Charm 1 (Pers), Acrobatics 1(Agi), Athletics 2(Str)
#
# 441
# Drops/Equipment:
#
# 442
# Attacks/Weapons:
#
# 443
# Draining Bite - Skill: Hand-to-Hand (YYGG) Range: Engaged, Damage: 5, Crit: 3, Qualities: +5 Drain 3
#
# 444
# Talents:
#
# 445
# Daedra - Unit is a Daedra for the purpose of spellcasting, and gains a 50% damage reduction from Normal Weapons.
#
# 446
# Insatiable - Every successful Drain effect cast or inflicted by the Hunger grants it a Boost for the next round.
#
# 447
# Special Abilities:
#
# 448
# Devour - Should a Hunger successfully bite a target, it can spend an action on its next round consuming the life force of the victim, draining 3 Wounds per round. It must remain attached to the target, and cannot attack anyone else, or the effect ends.
#
# 449
#
# 450
# Lurker [Nemesis]
#
# 451
# Lurkers are large daedric creatures that guard the murky waters of Hermaeus Mora's realm of Apocrypha. They appear as amphibious humanoids who serve their Prince by guarding forbidden knowledge. Lurkers use their long legs for stomping attacks, and can attack from afar by spewing tentacles from their mouths.
#
# 452
#
# 453
# Strength Endurance Agility Intellect Willpower Personality
#
# 454
# 5 5 3 2 3 1
#
# 455
#
# 456
# Soak: 6
#
# 457
# Wounds: 33
#
# 458
# Skills: Hand-to-Hand 4(Str), Athletics 3(Str), Resilience 5(End), Intimidate 3(Str), Vigilance 3(Will), Marksman 3(Agi)
#
# 459
# Drops/Equipment:
#
# 460
# Attacks/Weapons:
#
# 461
# Jagged Boots- Skill: Hand-to-Hand(Str) (YYYYG) Range: Engaged, Damage: 9, Crit: 3, Qualities: Knockdown
#
# 462
# Tentacle Spew- Skill: Marksman(Agi) (YYY) Range: Medium, Damage: 6, Crit: 2, Qualities: Disorient 1
#
# 463
# Talents:
#
# 464
# Daedra - Unit is a Daedra for the purpose of spellcasting, and gains a 50% damage reduction from Normal Weapons.
#
# 465
# Adversary 2 - Upgrade 2 difficulty dice to all checks targeting this character.
#
# 466
# Normal Weapon Immunity - Takes no damage from Normal Weapons.
#
# 467
# Large - Lurkers possess a Silhouette of 3.
#
# 468
# Special Abilities:
#
# 469
# Submerge - When out of combat, a Lurker can submerge itself fully into any body of water, no matter how deep. As a maneuver, it can emerge again.
#
# 470
#
# 471
# Ogrim [Nemesis]
#
# 472
# These are enormous Daedra with very little intellect, but which are chiefly sent into the mortal world to menace living things for the amusement of the Daedric Prince Malacath. Hefty, with thick hide and an immunity to Normal Weapons, Ogrim are rightfully feared.
#
# 473
#
# 474
# Strength Endurance Agility Intellect Willpower Personality
#
# 475
# 5 6 2 1 2 1
#
# 476
#
# 477
# Soak: 10/6
#
# 478
# Wounds: 32
#
# 479
# Skills: Hand-to-Hand 4(Str), Athletics 3(Str), Resilience 5(End), Intimidate 3(Str), Vigilance 3(Will)
#
# 480
# Drops/Equipment: Daedra Heart (Exceptional Herb)
#
# 481
# Attacks/Weapons:
#
# 482
# Bludgeoning Fists - Skill: Hand-to-Hand(Str) (YYYYG) Range: Engaged, Damage: 8, Crit: 4, Qualities: Knockdown, Disorient 2
#
# 483
# Talents:
#
# 484
# Daedra - Unit is a Daedra for the purpose of spellcasting, and gains a 50% damage reduction from Normal Weapons.
#
# 485
# Adversary 2 - Upgrade 2 difficulty dice to all checks targeting this character.
#
# 486
# Normal Weapon Immunity - Takes no damage from Normal Weapons.
#
# 487
# Large - Ogrim possess a Silhouette of 3.
#
# 488
# Special Abilities:
#
# 489
# Body Slam - Spend 1 Story Point to add Endurance to the damage of one melee attack.
#
# 490
#
# 491
# Scamp [Minion]
#
# 492
# One of the lesser sentient Daedra of Oblivion, Scamps often enter into the mortal world to cause mischief and carry out errands for their Princes. They are weak, rather unintelligent, cowardly, and are easily defeated except in large numbers. They are most commonly associated with Mehrunes Dagon.
#
# 493
#
# 494
# Strength Endurance Agility Intellect Willpower Personality
#
# 495
# 1 2 3 1 2 1
#
# 496
#
# 497
# Soak: 3/3
#
# 498
# Wounds: 7
#
# 499
# Skills: Hand-to-Hand (Agi), Athletics (Str), Destruction (Will), Resilience (End), Intimidate (Str), Vigilance (Will)
#
# 500
# Drops/Equipment:
#
# 501
# Attacks/Weapons:
#
# 502
# Claws- Skill: Hand-to-Hand(Agi) (GGG) Range: Engaged, Damage: 5, Crit: 3, Qualities: Pierce 1
#
# 503
# Magic Actions:
#
# 504
# Firebolt - Skill: Destruction(Will)(GG) Difficulty: Average Range: Medium, Damage: 5, Crit: 4, Qualities: Burn 3
#
# 505
# Talents:
#
# 506
# Daedra - Unit is a Daedra for the purpose of spellcasting, and gains a 50% damage reduction from Normal Weapons.
#
# 507
# Pack - Scamps work well in groups. All actions gain Boost when Grouped.
#
# 508
#
# 509
# Seeker [Rival]
#
# 510
# Seekers are grotesque tentacled daedra. They are servants of Hermaeus Mora, usually guarding tomes of forbidden knowledge. Seekers have the power to banish prey with sound attacks. They are rarely seen outside the Apocrypha.
#
# 511
#
# 512
# Strength Endurance Agility Intellect Willpower Personality
#
# 513
# 1 1 3 5 3 2
#
# 514
#
# 515
# Soak: 2/5
#
# 516
# Wounds: 12
#
# 517
# Magicka: 16
#
# 518
# Skills: Hand-to-Hand 1(Agi), Marksman 2(Agi), Illusion 3(Pers), Destruction 2(Will), Mysticism 2(Will), Conjuration 3(Int), Necromancy 2(Int)
#
# 519
# Drops/Equipment:
#
# 520
# Attacks/Weapons:
#
# 521
# Tentacle Strike- Skill: Hand-to-Hand (YGG) Range: Engaged, Damage: 6, Crit: 3, Qualities: +6 Poison Damage
#
# 522
# Voice of Apocrypha - Skill: Marksman (YYG) Range: Medium, Damage: 7, Crit: 3, Qualities: Disorient 1, Pierce 1
#
# 523
# Talents:
#
# 524
# Daedra - Unit is a Daedra for the purpose of spellcasting, and gains a 50% damage reduction from Normal Weapons.
#
# 525
# Special Abilities:
#
# 526
# Submerge - When out of combat, a Seeker can submerge itself fully into any body of water, no matter how deep. As a maneuver, it can emerge again.
#
# 527
# Horror Story - Once per round, Seeker may choose to use the Horror Story Action. A target within Medium range must pass a competing Fear check against the Seeker’s Illusion skill, or suffer fear effects.
#
# 528
#
# 529
# Spider Daedra [Rival]
#
# 530
# These Daedra appear as giant spiders with human torsos, and are associated with Mephala. They are so fiercely independent, deceptive and irrational that not even Mephala's worshippers will often summon them, for fear that they will disobey orders. They are some of the more powerful Daedra, with high intelligence, combat prowess, and magical ability.
#
# 531
#
# 532
# Strength Endurance Agility Intellect Willpower Personality
#
# 533
# 2 3 4 4 3 4
#
# 534
#
# 535
# Soak: 4
#
# 536
# Wounds: 16
#
# 537
# Skills: Acrobatics 2(Agi), Charm 3(Pers), Deception 2(Pers), One-Handed 2(Agi), Hand-to-Hand 2(Agi), Necromancy 1(Int), Destruction 1(Will), Conjuration 2(Int), Illusion 3(Pers)
#
# 538
# Drops/Equipment:
#
# 539
# Attacks/Weapons:
#
# 540
# Razor Nails - Skill: Hand-to-Hand(Agi) (YYGG) Range: Engaged, Damage: 6, Crit: 3, Qualities: Pierce 2
#
# 541
# Magic Actions:
#
# 542
# Stunning Gaze - Skill: Destruction(Will)(YGG) Difficulty: Average Range: Medium, Effects: Target is Staggered for one round.
#
# 543
# Summon Lesser Daedra - Skill: Conjuration(Int)(YYGG) Difficulty: Average Range: Medium, Effects: Summon 1 Minion Daedra within Medium range, persisting for one round per Success, unless a maneuver is spent on Concentration.
#
# 544
# Talents:
#
# 545
# Daedra - Unit is a Daedra for the purpose of spellcasting, and gains a 50% damage reduction from Normal Weapons.
#
# 546
# Unpredictable - Gain Boost to all Charm and Deception checks.
#
# 547
#
# 548
# Winged Twilight [Rival]
#
# 549
# Described as both beautiful and grotesque, Winged Twilight resemble an attractive woman with long, bat-like wings in place of arms, and dusky blue-grey skin. Oftentimes mistaken as Harpies, Twilights serve Azura as messengers and agents.
#
# 550
#
# 551
# Strength Endurance Agility Intellect Willpower Personality
#
# 552
# 2 2 4 2 2 3
#
# 553
#
# 554
# Soak: 3
#
# 555
# Wounds: 14
#
# 556
# Skills: Acrobatics 3(Agi), Charm 3(Pers), Deception 2(Pers), One-Handed 2(Agi), Hand-to-Hand 2(Agi), Destruction 1(Will), Conjuration 2(Int), Illusion 3(Pers)
#
# 557
# Drops/Equipment:
#
# 558
# Attacks/Weapons:
#
# 559
# Talons - Skill: Hand-to-Hand(Agi)(YYGG) Range: Engaged, Damage: 7, Crit: 3, Qualities: Pierce 1
#
# 560
# Talents:
#
# 561
# Daedra - Unit is a Daedra for the purpose of spellcasting, and gains a 50% damage reduction from Normal Weapons.
#
# 562
# Glide - Winged Twilights can use their wings to glide from one location to another, increasing their movement speed while falling to a 3, and making them immune to fall damage.
#
# 563
# Special Abilities:
#
# 564
# Soar - Once per encounter, a Winged Twilight adopts the Flier attribute, with a speed of 3. This lasts for one round.
#
# 565
#
# 566
# Xivilai [Nemesis]
#
# 567
# Xivilai are highly intelligent Daedra that look like tall and muscular gray-skinned warriors. They are similar in many points to the Dremora, but do not have a caste system. Their lack of a caste system fits perfectly with their hatred of subordination and tendency for betrayal. They are immensely strong, and gifted with magic.
#
# 568
#
# 569
# Strength Endurance Agility Intellect Willpower Personality
#
# 570
# 5 4 4 6 3 6
#
# 571
#
# 572
# Soak: 5
#
# 573
# Wounds: 31
#
# 574
# Strain: 26
#
# 575
# Defense: 1/1
#
# 576
# Skills: Athletics 3(Str), Acrobatics 2(Agi), Charm 4(Pers), Conjuration 4(Int), Cool 4 (Will), Deception 4(Pers), Destruction 4(Will), Intimidate 4 (Str), Illusion 4(Pers), Resilience 2 (End), Search 2(Will), Vigilance 2(Will)
#
# 577
# Drops/Equipment: Daedra Heart, All Weapons/Armour below
#
# 578
# Attacks/Weapons:
#
# 579
# Burning Claws - Skill: One-Handed(Agi) (YYYG) Range: Engaged, Damage: 7, Crit: 3, Qualities: Pierce 3, Vicious 2, +6 Fire Damage
#
# 580
# Talents:
#
# 581
# Confidence 4 - Dremora Valyknaz reduce the difficulty of Fear checks by 4.
#
# 582
# Adversary 2 - Upgrade 2 difficulty dice to all checks targeting this character.
#
# 583
# Daedra - Unit is a Daedra for the purpose of spellcasting, and gains a 50% damage reduction from Normal Weapons.
#
# 584
# Normal Weapon Immunity - Takes no damage from Normal Weapons.
#
# 585
# Determination - Summoned Dremora are exceptionally opposed to returning to Oblivion, and thus gain 2 Boost to all Banish spell checks.
#
# 586
# Special Abilities:
#
# 587
# Command - As a maneuver, Valyknaz can grant Boost dice to the next action performed by an allied Caitiff or Kynreeve.
#
# 588
# Aura of Terror - When a Valyknaz enters combat, all characters who are aware of him, must pass a Hard (3) Cool Fear check.
#
# 589
#
# 590
# Random Daedra
#
# 591
# Random Lesser Daedra Table:
#
# 592
#
# 593
# % Lesser Daedra
#
# 594
# 1-20 Atronach, Fire
#
# 595
# 21-50 Clannfear, Runt
#
# 596
# 51-85 Scamp
#
# 597
# 86-90 Dark Seducer, Kiskengo
#
# 598
# 91-95 Dremora, Caitiff
#
# 599
# 96-100 Golden Saint, Auren
#
# 600
#
# 601
# Random Daedra Table:
#
# 602
#
# 603
# % Daedra
#
# 604
# 1-5 Auroran
#
# 605
# 5-20 Atronach, Frost
#
# 606
# 21-35 Clannfear
#
# 607
# 36-50 Seeker
#
# 608
# 51-65 Spider Daedra
#
# 609
# 66-80 Winged Twilight
#
# 610
# 81-85 Harvester
#
# 611
# 86-90 Hunger
#
# 612
# 91-94 Dark Seducer, Autkendo
#
# 613
# 95-97 Dremora, Kynreeve
#
# 614
# 98-100 Golden Saint, Aurmokel
#
# 615
#
# 616
# Random Greater Daedra Table:
#
# 617
#
# 618
# % Daedra
#
# 619
# 1-16 Atronach, Storm
#
# 620
# 17-32 Daedroth
#
# 621
# 33-48 Lurker
#
# 622
# 49-64 Ogrim
#
# 623
# 65-80 Xivilai
#
# 624
# 81-87 Dark Seducer, Grakendo
#
# 625
# 88-94 Dremora, Valyknaz
#
# 626
# 95-100 Golden Saint, Pelaurig
#
# 627

# %%
#This works for rivals. I'll copy it for a nemesis just to make sure I don't break it

# I think the dudes with spells, and the complicated ones like the Dreadgazer, need to be done manually
folder = "D:\\Git Projects\\genesys-adversaries\\src\\media\\data\\adversaries\\"
#I will use this to keep track of all of the abilities with full text to see what I can replace
All_Abilities_List = []
All_Abilities_List_name_only = []
JSONtext = ''

char_list = ["Strength","Endurance", "Agility","Intellect","Willpower","Personality"]
    
EoTCreatures = open(folder + "EoT Adversaries.txt","r")

#Start at 999999 so when I use the initial between it's always false, but then after we set the ability
#line it works
ability_line_num = 999999
description_line_num = 999999
char_line_num = 999999
weapon_line_num = 999999

for line_num,line_full in enumerate(EoTCreatures):
    #print line_num
    line = line_full
    #Firstly, I want to replace all the dots and tabs and double-spaces with single spaces to make parsing easier
    line = line_full.replace('●',' ')
    line = line.lstrip()
    line = line.replace('\t', ' ')
    while line.find("  ") > -1:
        line = line.replace('  ', ' ')
    #I also want to remove trailing spaces from lines
    line = line.replace(' \n','\n')
    
    
    #For the first line, we know it starts with the name, type, and description
    #print('Line Number: ' + str(line_num))
    #Print where I expect the characteristic text to be
    #print(line[:line.find(":")] in char_list)
    if line.find("[Minion]") > -1 or line.find("[Rival]") > -1 or line.find("[Nemesis]") > -1:
    #if line_num == 0:
        #Grab the character name
        JSONtext += '\t{\n\t\t"name": "'
        p1 = line.find(" [")
        JSONtext += line[:p1] + '",\n\t\t"source": { "owner": "MyriadPro", "url": \
"https://community.fantasyflightgames.com/topic/269367-myriadpros-edge-of-tamriel-second-edition-name-change/" }, \
\n\t\t"type": "'

        #Grab the type
        p2 = line.find("]")
        adversary_type = line[p1+2:p2]
        JSONtext += adversary_type + '",\n\t\t"description": "'
        
        description_line_num = line_num + 1

        #Grab the description, which is on the next line (or two)
    if line_num == description_line_num:
        #p1 = p2 + 3
        #p2 = line.find("\n")
        JSONtext += line.replace('\n', '') + '",\n\t\t"characteristics": {' #\n\t\t\t"Brawn": '
        #Reset for the next adversary
        description_line_num = 999999
        
    #if line[:line.find(" ")] in char_list:
    if line.replace('\n', '') == 'Strength Endurance Agility Intellect Willpower Personality':
        char_line_num = line_num + 1
        #print(line_num)
        
    #Check the next line
    if line_num == char_line_num:
        #Loop through characteristics
        for c_pos,c in enumerate(char_list):
            #print(line.find(c))
                #print(line)
                if c == "Personality":
                    JSONtext += '\n\t\t\t"' + c + '": ' + line[c_pos*2:c_pos*2+1] + '\n\t\t},\n\t\t"derived": {'
                else:
                    #print('\n\t\t\t"' + c + '": ' + line[p1:p1+1] + ',')
                    #p2 = re.search('[0-9]', line)
                    JSONtext += '\n\t\t\t"' + c + '": ' + line[c_pos*2:c_pos*2+1] + ','
        char_line_num = 999999
            
    if line[:line.find(":")] in ["Soak","Wounds", "Strain", "Defense"]:
        #Loop through derived characteristics (for rivals at least)
        for d in ["Soak","Wounds", "Strain", "Defense"]:
            if line.find(d) > -1:
                p1 = line.find(d) + len(d) + 2
                p2 = line.find(' ',p1)
                #I need to use [,] instead of /
                #Soak is always first, but the others can be in any other order
                if d == "Defense":
                    #I'm assuming the defence will always be single digits
                    JSONtext += ',\n\t\t\t"defence": [' + line[p1:p1+1] + ',' + line[p1+2:p1+3] + ']'
                else:
                    JSONtext += ',\n\t\t\t"' + d.lower() + '": ' + line[p1:p2]
                    
    #This is to make sure I start with the correct bracket
    if line[:line.find(":")] == "Skills":
        if adversary_type == 'Minion':
            JSONtext += '\n\t\t},\n\t\t"skills": ['
        else:
            JSONtext += '\n\t\t},\n\t\t"skills": {'
    #All skills have the linked characteristic in brackets
    if line[:line.find(":")] == "Skills":
        #Skills: Charm (Pers), Deception (Pers), Destruction (Will)
        #Skills: Charm 1 (Pers), Deception 1 (Pers), Destruction 2 (Will)
        SkillSplit = line.replace('\n','')[line.find(":")+2:].split(", ")
        for s in SkillSplit:
            #Minion skills have no number
            #print s
            #Assume no skill names have a space
            if adversary_type == 'Minion':
                JSONtext += '"' + s[:s.find('(')].replace(' ','') + '",'
            else:
                #I'm assuming the skills will always be single digits
                JSONtext += '\n\t\t\t"' + s[:s.find('(')].replace(' ','')[:-1] + '": ' + s[:s.find('(')].replace(' ','')[-1:] + ","
        #Now take off that final comma
        #I should check here for talents, probably, but let's go one example at a time
        JSONtext = JSONtext[:len(JSONtext)-1]
        #This is to make sure I end with the correct bracket
        if line[:line.find(":")] == "Skills":
            if adversary_type == 'Minion':
                #JSONtext += '],\n\t\t"abilities": ['
                JSONtext += ']'
            else:
                #JSONtext += '\n\t\t},\n\t\t"abilities": ['
                JSONtext += '\n\t\t},'
        
    if line[:line.find(":")] == "Drops/Equipment":
        #Put this stuff in gear
        #Drops/Equipment: Fire Salts - Counts as Rare Herb
        #"gear": ["Rumpled clothing","Endless stacks of holoscrolls","Databooks","Forms-lots of forms"],
        JSONtext += ',\n\t\t"gear": ["' + line[line.find(':')+2:].replace('\n','') + '"],'
    
    if line[:line.find(":")] == "Attacks/Weapons":
        weapon_line_num = line_num + 1
        
    if line.find("Skill:") == -1 and line_num >= weapon_line_num:
        weapon_line_num = 999999
        
    if line_num >= weapon_line_num:
        #Now take off that final comma and space from the abilities
        JSONtext = JSONtext[:len(JSONtext)-2] + '],\n\t\t"weapons": ['
        #WeaponSplit = line.replace('\n','')[line.find(":")+2:].split("), ")
        #Trying to keep the delimiters
        #d = "), "
        #To make this delimiting easier
        #newlinetext = line.replace('\n','')[line.find(":")+2:] + ", "
        #print newlinetext
        #WeaponSplit =  [e+")" for e in newlinetext.split("), ")]
        #for w in WeaponSplit:
            #First, make sure it's a weapon
            #print w
        if line.find("Damage") > -1:
            #Jagged Boots- Skill: Hand-to-Hand(Str) (YYYYG) Range: Engaged, Damage: 9, Crit: 3, Qualities: Knockdown
            #2x Daedric Shortsword- Skill: One-Handed(Agi) (YYYY) Range: Engaged, Damage: 6, Crit: 3, Qualities: Pierce 3, Vicious 2
            JSONtext += '\n\t\t\t{\n\t\t\t\t"name": "' + line[:line.find("-")] + '",\n\t\t\t\t'
            WeaponStatSplit = line[line.find("-")+1:].replace('\n','').split(": ")
            print WeaponStatSplit
            #[['Skill'],['One-Handed(Agi) (YYYY) Range'],['Engaged, Damage'],['6, Crit'],['3, Qualities'],['Pierce 3, Vicious 2']]
            #First is skill
            JSONtext += '"skill": "' + WeaponStatSplit[1][:WeaponStatSplit[1].find('(')].replace(' ','') + '",\n\t\t\t\t'
            #Then the damage
            JSONtext += '"damage": ' + WeaponStatSplit[3][:WeaponStatSplit[3].find(',')] + ',\n\t\t\t\t'
            #Then the critical rating
            JSONtext += '"critical": ' + WeaponStatSplit[4][0] + ',\n\t\t\t\t'
            #Then the range
            JSONtext += '"range": "' + WeaponStatSplit[2][:WeaponStatSplit[2].find(",")] + '",\n\t\t\t\t'
            #Now get the special qualities. Get rid of that trailing bracket
            Qualities = WeaponStatSplit[5].split(", ")
            JSONtext += '"qualities": ['
            for q in Qualities:
                #print q
                JSONtext += '"' + q + '",'
            #Now take off that final comma after the last quality
            JSONtext = JSONtext[:len(JSONtext)-1] + ']\n\t\t\t},'
            
                  
    if line[:line.find(":")] == "Special Abilities":
        ability_line_num = line_num
        
    if line == "\n" and line_num > ability_line_num:
        ability_line_num = 999999
        
    #This needs to handle the next few lines of abilities
    if line_num > ability_line_num:
        #print line
        #I think this split is pointless as they are always on separate lines
        #AbilitySplit = line.replace('\n','').replace('Abilities: ', '').split(", ")
        #Ability = line.replace('\n','').replace('Special Abilities: ', '')
        Ability = line
        #print Ability
        #Keep track of all of the abilities to see what I can make generic
        All_Abilities_List.append(Ability)
        All_Abilities_List_name_only.append(Ability[:Ability.find(" - ")])
        JSONtext += '\n\t\t\t{\n\t\t\t\t"name": "' + Ability[:Ability.find(" - ")] + '", \n\t\t\t\t"description": "' + \
                        Ability[Ability.find(" - ")+3:].replace('\n','') + '"\n\t\t\t}, '
                
        #Once all of the weapons are done, add the gear line and then loop through again
        #But first, take off the final comma from the last weapon
        #Somehow, only run this if there is an item of gear without damage...
        '''
        JSONtext = JSONtext[:len(JSONtext)-1] + '\n\t\t],\n\t\t"gear": ['
        for w in WeaponSplit:
            if w.find("Damage") == -1 and w.find("(") > -1:
                JSONtext += '"' + w + '",'
        '''
        #Now take off that final comma after the last item
        #Plus, add the tags. I won't try species or category tags yet, just source and CR
        #Worry about gear later
        #JSONtext = JSONtext[:len(JSONtext)-1] + '],\n\t\t"tags": [' + \
        JSONtext = JSONtext[:len(JSONtext)-1] + '\n\t\t],\n\t\t"tags": [' + \
                        '"source:Edge of Tamriel", "Homebrew", "Fantasy", "Undead", ' + \
                        '"Combat CR:TBD", "Social CR:TBD", "General CR:TBD"]\n\t},\n'
    
#Still need to handle Magic Action and Talents (most of which are abilities I think)
#    if line_num >= 23:
#        break

from collections import Counter

print 'Duplicate abilities with exact text match:'
for a in Counter(All_Abilities_List):
    if Counter(All_Abilities_List)[a] > 1:
        print a
        
print 'Duplicate abilities with name match:'
for a in Counter(All_Abilities_List_name_only):
    if Counter(All_Abilities_List_name_only)[a] > 1:
        print a
        
#After going through all of that, remove the final ,
JSONtext = JSONtext[:-2]
#print JSONtext
EoTCreatures.close()

JSONformatFile = open(r"EoT Adversaries JSON.json","w+")
JSONformatFile.write(JSONtext)
JSONformatFile.close()
# Out:
# [' Skill', 'Hand-to-Hand(Agi)(GG) Range', 'Engaged, Damage', '7, Crit', '4, Qualities', 'Burn']
# [' Skill', 'Hand-to-Hand(Str)(YYY) Range', 'Engaged, Damage', '5, Crit', '4, Qualities', 'Knockdown, Disorient 2']
# [' Skill', 'Hand-to-Hand(Str)(YYY) Range', 'Engaged, Damage', '8, Crit', '4, Qualities', 'Knockdown, Disorient 2']
# [' Skill', 'Hand-to-Hand (Agi) (YYYG) Range', 'Engaged, Damage', '6, Crit', '3, Qualities', 'Pierce 1']
# [' Skill', 'Hand-to-Hand (Agi) (GGG) Range', 'Engaged, Damage', '5, Crit', '3, Qualities', 'Pierce 1']
# [' Skill', 'One-Handed (Agi) (G) Range', 'Engaged, Damage', '2, Crit', '2, Qualities', 'Normal Weapon, Enchanted, Pierce 1']
# [' Skill', 'Hand-to-Hand(Agi) (YYGG) Range', 'Engaged, Damage', '7, Crit', '3, Qualities', 'Pierce 2, Vicious 2, Bleed 2']
# [' Skill', 'Hand-to-Hand(Str) (YYGGG) Range', 'Range, Damage', '6, Crit', '2, Qualities', 'Pin, Sunder']
# [' Skill', 'One-Handed(Agi) (GG) Range', 'Engaged, Damage', '7, Crit', '3, Qualities', 'Pierce 3, Vicious 2']
# [' Skill', 'Marksman(Agi) (GG) Range', 'Medium, Damage', '8, Crit', '3, Qualities', 'Pierce 3, Vicious 2']
# [' Skill', 'One-Handed(Agi) (YYG) Range', 'Engaged, Damage', '8, Crit', '3, Qualities', 'Pierce 3, Vicious 2']
# [' Skill', 'Two-Handed(Str) (YYG) Range', 'Engaged, Damage', '9, Crit', '2, Qualities', 'Pierce 3, Vicious 2, Cumbersome 4']
# [' Skill', 'Marksman(Agi) (YGG) Range', 'Medium, Damage', '8, Crit', '3, Qualities', 'Pierce 3, Vicious 2']
# [' Skill', 'One-Handed(Agi) (YYYG) Range', 'Engaged, Damage', '8, Crit', '3, Qualities', 'Pierce 3, Vicious 2']
# [' Skill', 'Two-Handed(Str) (YYYY) Range', 'Engaged, Damage', '10, Crit', '2, Qualities', 'Pierce 3, Vicious 2, Cumbersome 3']
# [' Skill', 'One-Handed(Agi) (GG) Range', 'Engaged, Damage', '7, Crit', '3, Qualities', 'Pierce 3, Vicious 2']
# [' Skill', 'Marksman(Agi) (GG) Range', 'Medium, Damage', '8, Crit', '3, Qualities', 'Pierce 3, Vicious 2']
# [' Skill', 'One-Handed(Agi) (YYG) Range', 'Engaged, Damage', '9, Crit', '3, Qualities', 'Pierce 3, Vicious 2']
# [' Skill', 'Two-Handed(Str) (YYGG) Range', 'Engaged, Damage', '10, Crit', '2, Qualities', 'Pierce 3, Vicious 2, Cumbersome 4']
# [' Skill', 'Marksman(Agi) (YGG) Range', 'Medium, Damage', '8, Crit', '3, Qualities', 'Pierce 3, Vicious 2']
# [' Skill', 'One-Handed(Agi) (YYYG) Range', 'Engaged, Damage', '10, Crit', '3, Qualities', 'Pierce 3, Vicious 2']
# [' Skill', 'Two-Handed(Str) (YYYYG) Range', 'Engaged, Damage', '11, Crit', '2, Qualities', 'Pierce 3, Vicious 2, Cumbersome 3']
# [' Skill', 'One-Handed(Agi) (GG) Range', 'Engaged, Damage', '7, Crit', '3, Qualities', 'Pierce 3, Vicious 2']
# [' Skill', 'Marksman(Agi) (GG) Range', 'Medium, Damage', '8, Crit', '3, Qualities', 'Pierce 3, Vicious 2']
# [' Skill', 'One-Handed(Agi) (YYG) Range', 'Engaged, Damage', '8, Crit', '3, Qualities', 'Pierce 3, Vicious 2']
# [' Skill', 'Two-Handed(Str) (YYG) Range', 'Engaged, Damage', '9, Crit', '2, Qualities', 'Pierce 3, Vicious 2, Cumbersome 4']
# [' Skill', 'Marksman(Agi) (YGG) Range', 'Medium, Damage', '8, Crit', '3, Qualities', 'Pierce 3, Vicious 2']
# [' Skill', 'One-Handed(Agi) (YYYG) Range', 'Engaged, Damage', '8, Crit', '3, Qualities', 'Pierce 3, Vicious 2']
# [' Skill', 'Two-Handed(Str) (YYYY) Range', 'Engaged, Damage', '10, Crit', '2, Qualities', 'Pierce 3, Vicious 2, Cumbersome 3']
# [' Skill', 'One-Handed(Agi) (YYYY) Range', 'Engaged, Damage', '6, Crit', '3, Qualities', 'Pierce 3, Vicious 2']
# [' Skill', 'Two-Handed(Str) (YYYG) Range', 'Engaged, Damage', '10, Crit', '2, Qualities', 'Pierce 3, Vicious 2, Cumbersome 4']
# [' Skill', 'Hand-to-Hand (YYGG) Range', 'Engaged, Damage', '5, Crit', '3, Qualities', '+5 Drain 3']
# [' Skill', 'Hand-to-Hand(Str) (YYYYG) Range', 'Engaged, Damage', '9, Crit', '3, Qualities', 'Knockdown']
# [' Skill', 'Marksman(Agi) (YYY) Range', 'Medium, Damage', '6, Crit', '2, Qualities', 'Disorient 1']
# [' Skill', 'Hand-to-Hand(Str) (YYYYG) Range', 'Engaged, Damage', '8, Crit', '4, Qualities', 'Knockdown, Disorient 2']
# [' Skill', 'Hand-to-Hand(Agi) (GGG) Range', 'Engaged, Damage', '5, Crit', '3, Qualities', 'Pierce 1']
# [' Skill', 'Hand-to-Hand (YGG) Range', 'Engaged, Damage', '6, Crit', '3, Qualities', '+6 Poison Damage']
# [' Skill', 'Marksman (YYG) Range', 'Medium, Damage', '7, Crit', '3, Qualities', 'Disorient 1, Pierce 1']
# [' Skill', 'Hand-to-Hand(Agi) (YYGG) Range', 'Engaged, Damage', '6, Crit', '3, Qualities', 'Pierce 2']
# [' Skill', 'Hand-to-Hand(Agi)(YYGG) Range', 'Engaged, Damage', '7, Crit', '3, Qualities', 'Pierce 1']
# [' Skill', 'One-Handed(Agi) (YYYG) Range', 'Engaged, Damage', '7, Crit', '3, Qualities', 'Pierce 3, Vicious 2, +6 Fire Damage']
# Duplicate abilities with exact text match:
#
# Skills: Athletics 3(Str), Acrobatics 2(Agi), Charm 2(Pers), Conjuration 3(Int), Cool 2 (Will), Deception 3(Pers), Illusion 3(Will), Intimidate 4 (Str), Marksman 2(Agi), One-Handed 3(Agi), Two-Handed 4(Str), Resilience 2 (End), Search 2(Will), Vigilance 2(Will)
#
# Soak: 4
#
# 4 4 4 3 5 3
#
# Wounds: 10
#
# Determination - Summoned Dremora are exceptionally opposed to returning to Oblivion, and thus gain 2 Boost to all Banish spell checks.
#
# Wounds: 7
#
# Soak: 5
#
# Normal Weapon Immunity - Takes no damage from Normal Weapons.
#
# Magic Actions:
#
# Strength Endurance Agility Intellect Willpower Personality
#
# Confidence 4 - Dremora Valyknaz reduce the difficulty of Fear checks by 4.
#
# Mad God’s Visage - Mazken and Aureals gain two Boost to all Illusion spell checks.
#
# Arrogance - Players suffer one Setback to all Cool or Leadership checks when attempting to sway a Mazken or Aureal.
#
# Shock Weakness - Increase damage taken from all Lightning effects by 1.
#
# 2 2 3 2 3 1
#
# Drops/Equipment: Clannfear Scales - counts as Rare Herb
#
# Wounds: 31
#
# Defense: 1/1
#
# Talents:
#
# Armour:
#
# Defense: 3/3
#
# Soak: 8
#
# Adversary 1 - Upgrade 1 difficulty dice to all checks targeting this character.
#
# Wounds: 26
#
# Mad God’s Visage - Mazken and Aureals gain two Boost to all Illusion spell checks..
#
# Wounds: 14
#
# Skills: Athletics (Str), Acrobatics (Agi), Charm (Pers), Cool(Will), Conjuration (Int), Deception (Pers), Illusion (Pers), Marksman (Agi), One-Handed (Agi), Two-Handed (Str), Resilience(End), Search (Will), Vigilance (Will)
#
# Daedra - Unit is a Daedra for the purpose of spellcasting, and gains a 50% damage reduction from Normal Weapons.
#
# Drops/Equipment: Daedra Heart, All Weapons/Armour below
#
# 3 3 3 3 4 2
#
# Drops/Equipment: Daedra Heart (Weapons/Armour considered “Bound” and non-lootable)
#
# Wounds: 16
#
# Adversary - Upgrade 1 difficulty dice to all checks targeting this character.
#
# Drops/Equipment:
#
# Wounds: 21
#
# Skills: Athletics 2(Str), Acrobatics 2(Agi), Charm 2(Pers), Conjuration 2(Int), Cool 2 (Will), Deception 2(Pers), Illusion 2(Pers), Intimidate 2 (Str), Marksman 1(Agi), One-Handed 2(Agi), Two-Handed 2(Str), Resilience 2 (End), Search 1(Will), Vigilance 1(Will)
#
# Soak: 2
#
# Attacks/Weapons:
#
# Adversary 2 - Upgrade 2 difficulty dice to all checks targeting this character.
#
# Duplicate abilities with name match:
#
# Soak: 8
# Adversary 2
# Adversary 1
# 2 2 3 2 3 1
# Soak: 2
# Soak: 5
# Soak: 4
# Confidence 4
# Confidence 2
# Confidence 3
# Defense: 3/3
# Daedra
# Drops/Equipment:
# Large
# Defense: 1/1
# Armour:
# Drops/Equipment: Daedra Heart, All Weapons/Armour below
# Mad God’s Visage
# Submerge
# Adversary
# Skills: Athletics 2(Str), Acrobatics 2(Agi), Charm 2(Pers), Conjuration 2(Int), Cool 2 (Will), Deception 2(Pers), Illusion 2(Pers), Intimidate 2 (Str), Marksman 1(Agi), One-Handed 2(Agi), Two-Handed 2(Str), Resilience 2 (End), Search 1(Will), Vigilance 1(Will)
# Command
# Arrogance
# Attacks/Weapons:
# Drops/Equipment: Clannfear Scales
# Wounds: 7
# Determination
# Wounds: 21
# Wounds: 26
# Magic Actions:
# 3 3 3 3 4 2
# Strength Endurance Agility Intellect Willpower Personality
# Jagged Hide
# Wounds: 31
# Lightning Immunity
# 4 4 4 3 5 3
# Aura of Terror
# Drops/Equipment: Daedra Heart (Weapons/Armour considered “Bound” and non-lootable)
# Beak and Claws
# Normal Weapon Immunity
# Shock Weakness
# Talents:
# Skills: Athletics (Str), Acrobatics (Agi), Charm (Pers), Cool(Will), Conjuration (Int), Deception (Pers), Illusion (Pers), Marksman (Agi), One-Handed (Agi), Two-Handed (Str), Resilience(End), Search (Will), Vigilance (Will)
# Wounds: 10
# Wounds: 16
# Skills: Athletics 3(Str), Acrobatics 2(Agi), Charm 2(Pers), Conjuration 3(Int), Cool 2 (Will), Deception 3(Pers), Illusion 3(Will), Intimidate 4 (Str), Marksman 2(Agi), One-Handed 3(Agi), Two-Handed 4(Str), Resilience 2 (End), Search 2(Will), Vigilance 2(Will)
# Wounds: 14
